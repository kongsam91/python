# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft
x=np.linspace(-6.28,6.28,1000)
y1=np.sin(x)
fft_x   =   fft(y1)
# y2=np.sin(x-3.14/2)
# y_sum=y1+y2

plt.plot(x,y1)
#plt.plot(x,fft_x)
plt.show()
